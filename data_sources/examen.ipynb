# %% [markdown]
# **Extraction de liens avec Python et BeautifulSoup**

# %%
import requests
from bs4 import BeautifulSoup

# Fonction pour extraire les liens des annonces à partir d'une URL donnée
def extract_links_from_page(url):
    # Obtenir le contenu HTML de la page
    response = requests.get(url)
    html_content = response.text

    # Analyser le contenu HTML avec BeautifulSoup
    soup = BeautifulSoup(html_content, "html.parser")

    # Trouver toutes les balises div avec la classe "table-responsive"
    divs_tables = soup.find_all("div", class_="table-responsive")

    # Liste pour stocker les liens
    links = []

    # Récupérer les liens contenus dans ces balises div
    for div in divs_tables:
        # Rechercher les balises <a> dans chaque div
        a_tags = div.find_all("a", href=True)
        # Ajouter les liens trouvés à la liste
        for a in a_tags:
            href = a['href']
            if href:
                links.append(href)

    return links

# %%
# URL de base
base_url = "https://www.malipages.com/avis-appels-offres/"

# %%
# Nombre de pages à scraper
num_pages = 2
# Définir une liste pour stocker les liens
url = []

# Parcourir chaque page et extraire les liens
for page_num in range(1, num_pages+1):
    page_url = f"{base_url}{page_num}/"
    # Afficher l'URL de la page
    print(page_url)

# %%
def extract_links_from_page(url):
    # Liste pour stocker les liens
    links = []

    # Obtenir le contenu HTML de la page
    response = requests.get(url)
    html_content = response.text

    # Analyser le contenu HTML avec BeautifulSoup
    soup = BeautifulSoup(html_content, "html.parser")

    # Trouver toutes les balises div avec la classe "col-xl-9 col-lg-8 col-xs-12"
    divs_col = soup.find_all("div", class_="col-xl-9 col-lg-8 col-xs-12")

    # Récupérer les liens contenus dans ces balises div
    for div in divs_col:
        # Rechercher les balises <a> dans chaque div
        links_tags = div.find_all("a", href=True)
        # Ajouter les liens trouvés à la liste
        for link_tag in links_tags:
            href = link_tag['href']
            if href:
                links.append(href)

    return links
# Out:
# a bytes-like object is required, not 'str'

# %%
# Liste pour stocker les liens
url_2 = []

# Nombre de pages à scraper
num_pages = 10

# Parcourir chaque page et extraire les liens
for page_num in range(1, num_pages+1):
    page_url = f"{base_url}{page_num}/"
    links_on_page = extract_links_from_page(page_url)
    url_2.extend(links_on_page)
# Out:
# 'html \n \n if(navigator.userAgent.match(/MSIE|Internet Explorer/i)||navigator.userAgent.match(/Trident\\/7\\..*?rv:11/i)){var href=document.location.href;if(!href.match(/[?&]nowprocket/)){if(href.indexOf("?")==-1){if(href.indexOf("#")==-1){document.location.href=href+"?nowprocket=1"}else{document.location.href=href.replace("#","?nowprocket=1#")}}else{if(href.indexOf("#")==-1){document.location.href=href+"&nowprocket=1"}else{document.location.href=href.replace("#","&nowprocket=1#")}}}} class RocketLazyLoadScripts{constructor(){this.v="1.2.5.1",this.triggerEvents=["keydown","mousedown","mousemove","touchmove","touchstart","touchend","wheel"],this.userEventHandler=this._triggerListener.bind(this),this.touchStartHandler=this._onTouchStart.bind(this),this.touchMoveHandler=this._onTouchMove.bind(this),this.touchEndHandler=this._onTouchEnd.bind(this),this.clickHandler=this._onClick.bind(this),this.interceptedClicks=[],this.interceptedClickListeners=[],this._interceptClickListeners(this),wi
# ...

# %%
def extract_links_from_page(url):
    # Liste pour stocker les liens
    links = []

    # Obtenir le contenu HTML de la page
    response = requests.get(url)
    html_content = response.text

    # Analyser le contenu HTML avec BeautifulSoup
    soup = BeautifulSoup(html_content, "html.parser")

    # Trouver toutes les balises div avec la classe "col-xl-9 col-lg-8 col-xs-12"
    divs_col = soup.find_all("div", class_="col-xl-9 col-lg-8 col-xs-12")

    # Récupérer les liens contenus dans ces balises div
    for div in divs_col:
        # Rechercher les balises <a> dans chaque div
        links_tags = div.find_all("a", href=True)
        # Ajouter les liens trouvés à la liste
        for link_tag in links_tags:
            href = link_tag['href']
            if href:
                links.append(href)

    return links

# %%
# Fonction pour extraire le titre et le contenu d'une page à partir de son URL
def extract_content_from_page(url):
    try:
        # Obtenir le contenu HTML de la page
        response = requests.get(url)
        html_content = response.text

        # Analyser le contenu HTML avec BeautifulSoup
        soup = BeautifulSoup(html_content, "html.parser")

        # Extraire le titre de la page
        title = soup.title.string.strip()

        # Extraire le contenu de la page en combinant le texte de toutes les balises <p>
        content = '\n'.join([p.get_text() for p in soup.find_all('p')])

        return title, content
    except Exception as e:
        print(f"Une erreur s'est produite lors de l'extraction du contenu de {url}: {e}")
        return None, None

# %%
import os
# Créer un dossier pour stocker les fichiers texte
output_folder = "/Users/Mory/Desktop/content"
os.makedirs(output_folder, exist_ok=True)

# %%
# Parcourir chaque URL dans url_2 et extraire le titre et le contenu de chaque page
for index, url in enumerate(url_2, start=1):
    # Vérifier si l'URL est valide
    if "http" not in url:
        print(f"L'URL {url} n'est pas valide.")
        continue

    # Extraire le titre et le contenu de la page
    title, content = extract_content_from_page(url)

    # Créer un nom de fichier unique pour chaque lien
    filename = f"page_{index}.txt"
    filepath = os.path.join(output_folder, filename)

    # Écrire le titre et le contenu dans le fichier texte
    with open(filepath, "w", encoding="utf-8") as file:
        file.write(f"Titre : {title}\n\n")
        file.write(f"Contenu :\n{content}\n\n\n")

# %% [markdown]
# Module 2 : Classement par mots-clés

# %% [markdown]
# Site Web sur les produits technologiques, de bureau et d'éducation (Class_1)
# Site Web de produits de consommation (Class_2)
# Site Web de produits d'outils et de quincaillerie industriels btp  (Class_3)

# %%
Fourniture_bureau = ['fourniture de bureau', 'materiel informatique', 'phone', 'Technologie', 'ordinateur', 'imprimante', ' consultant', 'Education','audit','comptable','financier','kit']
btp = ['Restaurantion', 'fourniture de mobiliers et d\'equipement', 'location de voiture', 'impermeables', 'bic ', 'craies', 'gant', 'produits', 'alimentation', 'entretien', 'Internet', 'abonnements']
autres = ['trauvaux', 'realisation', 'rehabilitation', 'transformation', 'hydrauliques', 'quincaillerie', 'Lockout', 'Towers', 'Drywall', 'Tools', 'Packaging', 'Measure', 'Tag ']
keywords=Fourniture_bureau + btp + autres

# %%
# !pip install flashtext

# %%
#on utilise keywordProcessor pour retrouver les mots clés dans notre text recu de l'url
from flashtext.keyword import KeywordProcessor

kp0=KeywordProcessor()
for word in keywords:
    kp0.add_keyword(word)
kp1=KeywordProcessor()
for word in Fourniture_bureau:
    kp1.add_keyword(word)
kp2=KeywordProcessor()
for word in btp:
    kp2.add_keyword(word)
kp3=KeywordProcessor()
for word in autres:
    kp3.add_keyword(word)

# %%
#Pour trouver la valeur en pourcentage de Matching_value, nous définissons une fonction pourcentage comme suit :
def percentage1(dum0,dumx):
    try:
        ans=float(dumx)/float(dum0)
        ans=ans*100
    except:
        return 0
    else:
        return ans

# %%
def find_class(text_from_html, kp0, kp1, kp2, kp3):
    x=str(text_from_html)
    y0 = len(kp0.extract_keywords(x))
    y1 = len(kp1.extract_keywords(x))
    y2 = len(kp2.extract_keywords(x))
    y3 = len(kp3.extract_keywords(x))
    Total_matches=y0   
    per1 = float(percentage1(y0,y1))
    per2 = float(percentage1(y0,y2))
    per3 = float(percentage1(y0,y3))
    if y0==0:
        Category='None'
    else:
        if per1>=per2 and per1>=per3:
            Category='Class_1'
        elif per2>=per3 and per2>=per1:
            Category='Class_2'
        elif per3>=per1 and per3>=per2:
            Category='Class_3'
    return Category

# %%
text_from_html
# Out:
# 'html \n \n if(navigator.userAgent.match(/MSIE|Internet Explorer/i)||navigator.userAgent.match(/Trident\\/7\\..*?rv:11/i)){var href=document.location.href;if(!href.match(/[?&]nowprocket/)){if(href.indexOf("?")==-1){if(href.indexOf("#")==-1){document.location.href=href+"?nowprocket=1"}else{document.location.href=href.replace("#","?nowprocket=1#")}}else{if(href.indexOf("#")==-1){document.location.href=href+"&nowprocket=1"}else{document.location.href=href.replace("#","&nowprocket=1#")}}}} class RocketLazyLoadScripts{constructor(){this.v="1.2.5.1",this.triggerEvents=["keydown","mousedown","mousemove","touchmove","touchstart","touchend","wheel"],this.userEventHandler=this._triggerListener.bind(this),this.touchStartHandler=this._onTouchStart.bind(this),this.touchMoveHandler=this._onTouchMove.bind(this),this.touchEndHandler=this._onTouchEnd.bind(this),this.clickHandler=this._onClick.bind(this),this.interceptedClicks=[],this.interceptedClickListeners=[],this._interceptClickListeners(this),wi
# ...

# %%
import os
folder_path = "/Users/Mory/Desktop/content"

output_file_name = "fichier_combiné.txt"
output_file_path = os.path.join(folder_path, output_file_name)
# Ouvre le fichier de sortie en mode écriture
with open(output_file_path, "w") as output_file:
    # Parcourt tous les fichiers dans le dossier
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        # Vérifie si le fichier est un fichier .txt
        if filename.endswith(".txt"):
            # Ouvre le fichier en mode lecture
            with open(file_path, "r") as input_file:
                # Lit le contenu du fichier et l'écrit dans le fichier de sortie
                category = find_class(input_file, kp0, kp1, kp2, kp3)
                
                output_file.write(category)
                # Ajoute une nouvelle ligne après chaque fichier pour séparer leur contenu
                output_file.write("\n")




# category = find_class(text_from_html, kp0, kp1, kp2, kp3)
# print(category)

# %%
def find_class(file_content, kp0, kp1, kp2, kp3):
    # Supposons que la variable kp0, kp1, kp2, kp3 soit définie
    y0 = len(kp0.extract_keywords(file_content))
    y1 = len(kp1.extract_keywords(file_content))
    y2 = len(kp2.extract_keywords(file_content))
    y3 = len(kp3.extract_keywords(file_content))
    
    # Logique de classification
    # Assurez-vous d'adapter cette logique à vos besoins
    if y0 == 0:
        Category = 'None'
    else:
        per1 = float(percentage1(y0, y1))
        per2 = float(percentage1(y0, y2))
        per3 = float(percentage1(y0, y3))
        
        if per1 >= per2 and per1 >= per3:
            Category = 'Fourniture_bureau'
        elif per2 >= per3 and per2 >= per1:
            Category = 'btp'
        elif per3 >= per1 and per3 >= per2:
            Category = 'autres'
    
    return Category

# # Chemin du dossier contenant les fichiers texte
# folder_path = "/Users/Mory/Desktop/content"
# output_file_name = "fichier_combiné.txt"
# output_file_path = os.path.join(folder_path, output_file_name)

# # Ouvre le fichier de sortie en mode écriture
# with open(output_file_path, "w") as output_file:
#     # Parcourt tous les fichiers dans le dossier
#     for filename in os.listdir(folder_path):
#         file_path = os.path.join(folder_path, filename)
#         # Vérifie si le fichier est un fichier .txt
#         if filename.endswith(".txt"):
#             # Ouvre le fichier en mode lecture
#             with open(file_path, "r") as input_file:
#                 # Lit le contenu du fichier
#                 file_content = input_file.read()
#                 # Utilise la fonction find_class pour classifier le contenu du fichier
#                 category = find_class(file_content, kp0, kp1, kp2, kp3)
#                 # Écrit la catégorie dans le fichier de sortie
#                 output_file.write(category)
#                 # Ajoute une nouvelle ligne après chaque fichier pour séparer leur contenu
#                 output_file.write("\n")

# %%
import csv

# Définir le chemin du dossier contenant les fichiers texte
folder_path = "/Users/Mory/Desktop/content"

# Définir le nom du fichier CSV de sortie
output_csv_name = "categorie.csv"

# Chemin complet du fichier CSV de sortie
output_csv_path = os.path.join(folder_path, output_csv_name)

# Ouvrir le fichier CSV de sortie en mode écriture
with open(output_csv_path, "w", newline="") as csvfile:
    # Créer un écrivain CSV
    csv_writer = csv.writer(csvfile)
    
    # Écrire l'en-tête du fichier CSV
    csv_writer.writerow(["Fichier", "Catégorie"])
    
    # Parcourir tous les fichiers dans le dossier
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        
        # Vérifier si le fichier est un fichier .txt
        if filename.endswith(".txt"):
            # Lire le contenu du fichier
            with open(file_path, "r") as input_file:
                file_content = input_file.read()
            
            # Utiliser la fonction find_class pour classifier le contenu du fichier
            category = find_class(file_content, kp0, kp1, kp2, kp3)
            
            # Écrire le nom du fichier et la catégorie dans le fichier CSV
            csv_writer.writerow([filename, category])

print("Les résultats ont été enregistrés dans le fichier CSV avec succès.")
# Out:
# Les résultats ont été enregistrés dans le fichier CSV avec succès.

# %%
import os
import csv

# Définir le chemin du dossier contenant les fichiers texte
folder_path = "/Users/Mory/Desktop/content"

# Définir le nom du fichier CSV de sortie
output_csv_name = "categorie.csv"

# Chemin complet du fichier CSV de sortie
output_csv_path = os.path.join(folder_path, output_csv_name)

# Ouvrir le fichier CSV de sortie en mode écriture
with open(output_csv_path, "w", newline="") as csvfile:
    # Créer un écrivain CSV
    csv_writer = csv.writer(csvfile)
    
    # Écrire l'en-tête du fichier CSV
    csv_writer.writerow([ "Categorie", "Contenu"])
    
    # Parcourir tous les fichiers dans le dossier
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        
        # Vérifier si le fichier est un fichier .txt
        if filename.endswith(".txt"):
            # Lire le contenu du fichier
            with open(file_path, "r") as input_file:
                file_content = input_file.read()
            
            # Utiliser la fonction find_class pour classifier le contenu du fichier
            category = find_class(file_content, kp0, kp1, kp2, kp3)
            
            # Écrire le nom du fichier, la catégorie et le contenu dans le fichier CSV
            csv_writer.writerow([filename, category, file_content])

print("Les résultats ont été enregistrés dans le fichier CSV avec succès.")
# Out:
# Les résultats ont été enregistrés dans le fichier CSV avec succès.

# %% [markdown]
# En utilisant une boucle sur la fonction ci-dessus, nous pouvons trouver la catégorie de tous les sites Web en fonction des mots-clés. Nous sauvegarderons les données classifiées dans un fichier Data.csv que nous utiliserons ultérieurement. Nous avons donc maintenant notre ensemble de données prêt à appliquer le réseau neuronal pour la classification.

# %% [markdown]
# Module 3 : Application du réseau de neurones

# %% [markdown]
# Dans l'implémentation suivante, nous créerons un réseau neuronal à partir de zéro et utiliserons le tokenizer de mots NLTK pour le prétraitement. Nous devons d’abord importer notre ensemble de données obtenu à partir des étapes ci-dessus et le charger dans une liste

# %%
import pandas as pd
data=pd.read_csv('categorie.csv')
data=data[data.Categorie != 'None']
data=data[data.Categorie != 'Nan']
data = data.dropna()

# %% [markdown]
# nettoyage des donnees

# %%
data.isna().sum()
# Out:
# Categorie    0
# Contenu      0
# dtype: int64

# %%
output_csv_name = "categorie.csv"
output_csv_path = "/Users/Mory/Desktop/content/" + output_csv_name
data.to_csv(output_csv_path, index=False)

# %%
train_data = []
for index,row in data.iterrows():
    train_data.append({"class":row["Categorie"], "sentence":row["Contenu"]})

# %% [markdown]
# Pour appliquer le réseau neuronal, nous devons convertir les mots du langage en notations mathématiques, qui seront utilisées pour les calculs. Nous formerons une liste de tous les mots de toutes les chaînes.

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem.snowball import FrenchStemmer

# Initialiser le stemmer français
stemmer = FrenchStemmer()

words = []
classes = []
documents = []
ignore_words = ['?']
# loop through each sentence in our training data
for pattern in train_data:
    # tokenize each word in the sentence
    w = nltk.word_tokenize(pattern['sentence'])
    # add to our words list
    words.extend(w)
    # add to documents in our corpus
    documents.append((w, pattern['class']))
    # add to our classes list
    if pattern['class'] not in classes:
        classes.append(pattern['class'])

# stem and lower each word and remove duplicates
words = [stemmer.stem(w.lower()) for w in words if w not in ignore_words]
words = list(set(words))

# remove duplicates
classes = list(set(classes))

print (len(documents), "documents")
print (len(classes), "classes", classes)
print (len(words), "unique stemmed words", words)
# Out:
# 618 documents
# 3 classes ['btp', 'Fourniture_bureau', 'autres']
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# Charger les données depuis le fichier CSV
data = pd.read_csv('categorie.csv')

# Connexion à la base de données MySQL
engine = create_engine('mysql+pymysql://root:root@localhost/test')

# Nom de la table dans la base de données MySQL
nom_table = 'test'

# Insérer les données dans la base de données MySQL
data[['Categorie','Contenu']].to_sql(nom_table, con=engine, if_exists='append', index=False)

print("Les données ont été insérées avec succès dans la table de la base de données MySQL.")
# Out:
# Les données ont été insérées avec succès dans la table de la base de données MySQL.

# %% [markdown]
# Maintenant, nous allons créer une liste de mots tokenisés pour le modèle et également créer un sac de mots en utilisant NLTK Lancaster Stemmer.

# %%
from nltk.stem.lancaster import LancasterStemmer
stemmer = LancasterStemmer()
# create our training data
training = []
output = []
# create an empty array for our output
output_empty = [0] * len(classes)

# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # stem each word
    pattern_words = [stemmer.stem(word.lower()) for word in pattern_words]
    # create our bag of words array
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    training.append(bag)
    # output is a '0' for each tag and '1' for current tag
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    output.append(output_row)

print ("# words", len(words))
print ("# classes", len(classes))
# Out:
# # words 4231
# # classes 3

# %% [markdown]
# Maintenant, nous effectuons le prétraitement final sur les données et créons quelques fonctions.

# %% [markdown]
# Sigmoid Function

# %%
def sigmoid(x):
    output = 1/(1+np.exp(-x))
    return output

# convert output of sigmoid function to its derivative
def sigmoid_output_to_derivative(output):
    return output*(1-output)

# %% [markdown]
# Fonction de nettoyage

# %%
def clean_up_sentence(sentence):
    # tokenize the pattern
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word
    sentence_words = [stemmer.stem(word.lower()) for word in sentence_words]
    return sentence_words

# %%
def bow(sentence, words, show_details=False):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words
    bag = [0]*len(words)  
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)

    return(np.array(bag))

# %% [markdown]
# La dernière fonction qui sera utilisée dans les réseaux de neurones : la fonction Think

# %%
def think(sentence, show_details=False):
    x = bow(sentence.lower(), words, show_details)
    if show_details:
        print ("sentence:", sentence, "\n bow:", x)
    # input layer is our bag of words
    l0 = x
    # matrix multiplication of input and hidden layer
    l1 = sigmoid(np.dot(l0, synapse_0))
    # output layer
    l2 = sigmoid(np.dot(l1, synapse_1))
    return l2

# %% [markdown]
# Nous sommes maintenant tous prêts à entraîner notre modèle de réseau neuronal. Nous allons l'implémenter via scratch et utiliserons la régression logistique dans chaque neurone. Avec une seule couche, mais avec 500 époques, nous entraînerons notre modèle. L'exemple de formation complet s'exécutera sur CPU.

# %%
def train(X, y, hidden_neurons=10, alpha=1, epochs=10000, dropout=False, dropout_percent=0.5):

    print ("Training with %s neurons, alpha:%s, dropout:%s %s" % (hidden_neurons, str(alpha), dropout, dropout_percent if dropout else '') )
    print ("Input matrix: %sx%s    Output matrix: %sx%s" % (len(X),len(X[0]),1, len(classes)) )
    np.random.seed(1)

    last_mean_error = 1
    # randomly initialize our weights with mean 0
    synapse_0 = 2*np.random.random((len(X[0]), hidden_neurons)) - 1
    synapse_1 = 2*np.random.random((hidden_neurons, len(classes))) - 1

    prev_synapse_0_weight_update = np.zeros_like(synapse_0)
    prev_synapse_1_weight_update = np.zeros_like(synapse_1)

    synapse_0_direction_count = np.zeros_like(synapse_0)
    synapse_1_direction_count = np.zeros_like(synapse_1)
        
    for j in iter(range(epochs+1)):

        # Feed forward through layers 0, 1, and 2
        layer_0 = X
        layer_1 = sigmoid(np.dot(layer_0, synapse_0))
                
        if(dropout):
            layer_1 *= np.random.binomial([np.ones((len(X),hidden_neurons))],1-dropout_percent)[0] * (1.0/(1-dropout_percent))

        layer_2 = sigmoid(np.dot(layer_1, synapse_1))

        # how much did we miss the target value?
        layer_2_error = y - layer_2

        if (j% 10000) == 0 and j > 10000:
            # if this 10k iteration's error is greater than the last iteration, break out
            if np.mean(np.abs(layer_2_error)) < last_mean_error:
                print ("delta after "+str(j)+" iterations:" + str(np.mean(np.abs(layer_2_error))) )
                last_mean_error = np.mean(np.abs(layer_2_error))
            else:
                print ("break:", np.mean(np.abs(layer_2_error)), ">", last_mean_error )
                break
                
        # in what direction is the target value?
        # were we really sure? if so, don't change too much.
        layer_2_delta = layer_2_error * sigmoid_output_to_derivative(layer_2)

        # how much did each l1 value contribute to the l2 error (according to the weights)?
        layer_1_error = layer_2_delta.dot(synapse_1.T)

        # in what direction is the target l1?
        # were we really sure? if so, don't change too much.
        layer_1_delta = layer_1_error * sigmoid_output_to_derivative(layer_1)
        
        synapse_1_weight_update = (layer_1.T.dot(layer_2_delta))
        synapse_0_weight_update = (layer_0.T.dot(layer_1_delta))
        
        if(j > 0):
            synapse_0_direction_count += np.abs(((synapse_0_weight_update > 0)+0) - ((prev_synapse_0_weight_update > 0) + 0))
            synapse_1_direction_count += np.abs(((synapse_1_weight_update > 0)+0) - ((prev_synapse_1_weight_update > 0) + 0))        
        
        synapse_1 += alpha * synapse_1_weight_update
        synapse_0 += alpha * synapse_0_weight_update
        
        prev_synapse_0_weight_update = synapse_0_weight_update
        prev_synapse_1_weight_update = synapse_1_weight_update

    now = datetime.datetime.now()

    # persist synapses
    synapse = {'synapse0': synapse_0.tolist(), 'synapse1': synapse_1.tolist(),
               'datetime': now.strftime("%Y-%m-%d %H:%M"),
               'words': words,
               'classes': classes
              }
    synapse_file = "synapses.json"

    with open(folder_path+synapse_file, 'w') as outfile:
        json.dump(synapse, outfile, indent=4, sort_keys=True)
    print ("saved synapses to:", synapse_file)

# %% [markdown]
# Et enfin nous entraînerons le modèle :

# %%
import numpy as np
import datetime
import json

import time

X = np.array(training)
y = np.array(output)

start_time = time.time()

train(X, y, hidden_neurons=10, alpha=0.1, epochs=10000, dropout=False, dropout_percent=0.2)

elapsed_time = time.time() - start_time
print ("processing time:", elapsed_time, "seconds")
# Out:
# Training with 10 neurons, alpha:0.1, dropout:False
# Input matrix: 618x4231    Output matrix: 1x3
# saved synapses to: synapses.json
# processing time: 130.32177257537842 seconds

# %% [markdown]
# La fonction pour tester les données :

# %%
# probability threshold
ERROR_THRESHOLD = 0.2
# load our calculated synapse values
synapse_file = 'contentsynapses.json' 
with open(synapse_file) as data_file: 
    synapse = json.load(data_file) 
    synapse_0 = np.asarray(synapse['synapse0']) 
    synapse_1 = np.asarray(synapse['synapse1'])

def classify(sentence, show_details=False):
    results = think(sentence, show_details)

    results = [[i,r] for i,r in enumerate(results) if r>ERROR_THRESHOLD ] 
    results.sort(key=lambda x: x[1], reverse=True) 
    return_results =[[classes[r[0]],r[1]] for r in results]
    #print ("\n classification: %s" % ( return_results))
    return return_results

# %% [markdown]
# Testons le modèle avec sa précision :

# %%
classify("L’EUMC s’est implantée au Mali avec le Projet d’Appui à la Scolarisation des Filles (PASCOFI), mise en œuvre dans les régions de Ségou, Mopti, Bandiagara et Douentza. Ce projet qui bénéficie de l’appui global du bureau EUMC à Ottawa, d’un soutien financier d’Affaires mondiales Canada (AMC), d’un appui technique de CGA/Technologie s’étalera sur 05 ans (du 01 Avril 2021 au 31 Mars 2026). L’objectif global du PASCOFI est de réduire les inégalités du genre et les disparités dans l’apprentissage et le rendement scolaire des filles vulnérables et touchées par le conflit armé dans les régions de Mopti et Ségou. Il s’agit spécifiquement de mobiliser les communautés en faveur de l’éducation des filles pour réduire les risques d’abandon scolaire ou d’accès à l’école liés à des facteurs d’insécurité ou de comportements socio-culturels. Pour améliorer la qualité et la prise en compte du genre dans le système d’enseignement, le projet appuiera les efforts du ministère de l’Éducation nationale pour former les enseignants et déployer un nouveau curriculum scolaire qui favorise des approches pédagogiques inclusives et soucieuses de la réduction des inégalités entre les filles et les garçons Des organisations, telles les Association des Mères d’Élèves et autre partie prenantes aux écoles, seront sensibilisées et formées sur les bonnes pratiques sanitaires et les droits sexuels et reproductifs, les mariages forcés et les grossesses précoces qui affectent le maintien de filles à l’écoles dans les deux régions.")
# Out:
# [['Fourniture_bureau', 0.9838722196282904]]

# %%
classify("Travaux Mots descripteurs : Isolation , Lieu principal d'exécution du marché : 36-46 Rue de Bercy 75012 - Paris Durée du marché (en mois) : 11 La consultation comporte des tranches : non La consultation prévoit une réservation de tout ou partie du marché : Non Marché alloti : Non Section 6 : Informations Complémentaires Visite obligatoire : Oui Détail sur la visite (si oui) :Voir Le Reglement De Consultation Date d'envoi du présent avis : 08/03/2024")
# Out:
# [['autres', 0.983957213345657]]

# %%
classify("L'avis implique un marché public Objet : Mission d'étude de l'Economie Circulaire dans le secteur du bâtiment et des travaux publics (BTP) du NPNRU de l'agglomération Roissy Pays de France Procédure : Procédure adaptée Forme du marché : Prestation divisée en lots : non Critères d'attribution : Offre économiquement la plus avantageuse appréciée en fonction des critères énoncés dans le cahier des charges (règlement de la consultation, lettre d'invitation ou document descriptif). Remise des off")
# Out:
# [['autres', 0.9990023385484459]]

# %%
classify("afin de financer les travaux de rénovation et de réhabilitation de certains logements et bâtiments administratifs et à l’intention d’utiliser une partie de ces fonds pour effectuer des paiements au titre du marché relatif aux travaux de construction de l’immeuble R+8 du siège de la Direction générale des impôts (DGI) en lot unique.Les travaux objets du présent appel d’offres sont en lot unique constituant un marché et consistent à la : Démolition des ouvrages existants et préparation du site ; Construction d’un nouveau complexe de bâtiments de type R + 8 à usage de bureaux, et d’un bâtiment annexe R+2 (amphithéâtre, restauration, réunions, formation, fitness, et lieux de cultes) ; Construction de deux bureaux de contrôle d’accès ‘bureaux et sous-sol parking; Construction d’un parking (R-1) et Voiries et Réseaux Divers (VRD).")
# Out:
# [['Fourniture_bureau', 0.8791219435579467]]

# %%
classify("La Direction Nationale des Productions des Industries Animales (DNPIA) à travers l’Intervention « Appui au Renforcement de l’Elevage et de l’Economie Pastorale dans la région de Koulikoro, invite les candidats a considéré l’additif objet des modifications qu’elle a opéré au niveau du bordereau des prix unitaires et du détail estimatif et quantitatif. Les candidats ayant retiré le Dossier d’Appel d’Offres peuvent obtenir ledit aditif à l’Enabel – Koulikoro- l’Intervention « Appui au Renforcement de l’Elevage et de la Pêche » (AREPK) ; auprès de M. Oumar KONATE, Assistant Technique National Passation des Marchés Publics à l’adresse mentionnée ci-après : Rue 668, Porte 71, Quartier Souban, Cell. 74 68 20 22, Tel. 21 26 27 86, BP 11 Koulikoro/Mali")
# Out:
# [['autres', 0.9915510994416207]]
